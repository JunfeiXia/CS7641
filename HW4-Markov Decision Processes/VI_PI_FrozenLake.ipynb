# %%
import gym
import numpy as np
import random
from timeit import default_timer as timer
from datetime import timedelta
import matplotlib.pylab as plt
import pandas as pd
import seaborn as sns

# %%
from gym.envs.toy_text.frozen_lake import generate_random_map, FrozenLakeEnv
np.random.seed(2)
sixteen = generate_random_map(16)
np.random.seed(44)
tvelve = generate_random_map(12)
MAPS = {
    "4x4": [
        "SFFF",
        "FHFH",
        "FFFH",
        "HFFG"
    ],
    "8x8": [
        "SFFFFFFF",
        "FFFFFFFF",
        "FFFHFFFF",
        "FFFFFHFF",
        "FFFHFFFF",
        "FHHFFFHF",
        "FHFFHFHF",
        "FFFHFFFG"
    ],
    "12x12": tvelve,
    "16x16": sixteen
}

# %%
def test_policy(env, policy, n_epoch=1000):
    rewards = []
    episode_counts = []
    for i in range(n_epoch):
        current_state = env.reset()
        current_state = current_state[0]
        ep = 0
        done = False
        episode_reward = 0
        while not done and ep < 1000:
            ep += 1
            act = int(policy[current_state])
            new_state, reward, _, done, _ = env.step(act)
            episode_reward += reward
            current_state = new_state
            
#         if ep>=1000:
#             print('over limit')
        rewards.append(episode_reward)
        episode_counts.append(ep)
    
    # all done
    mean_reward = sum(rewards)/len(rewards)
    mean_eps = sum(episode_counts)/len(episode_counts)
    return mean_reward, mean_eps, rewards, episode_counts

# %%
def value_iteration(env, discount=0.9, epsilon=1e-12):
    
    start = timer()
    
    number_of_states = env.observation_space.n
    number_of_actions = env.action_space.n
    policy = np.zeros((1, number_of_states))
    value_list = np.zeros((1, number_of_states))
    old_value_list = value_list.copy()
    episode = 0
    max_change = 1
    sigma = discount
    while max_change > epsilon:
        episode += 1
        for s in range(number_of_states):
            assigned_value = -np.inf
            for a in range(number_of_actions):
                # get new state and its reward        
                total_cand_value = 0
                for prob, new_state, reward, done in env.P[s][a]:
                    # get new states value
                    value_new_state = old_value_list[0][new_state]
                    cand_value = 0
                    if done:
                        cand_value = reward 
                    else:
                        cand_value = reward + sigma*value_new_state
                    total_cand_value += cand_value*prob 
                        
                if total_cand_value > assigned_value:
                    assigned_value = total_cand_value
                    policy[0][s] = a
                    value_list[0][s] = assigned_value
        changes = np.abs(value_list - old_value_list)
        max_change = np.max(changes)
        old_value_list = value_list.copy()
        
    end = timer()
    time_spent = timedelta(seconds=end-start)
    print("Solved in: {} episodes and {} seconds".format(episode, time_spent))
    return policy[0], episode, time_spent

# %%
def policy_iteration(env, discount=0.9, epsilon=1e-3):
    
    start = timer()
    
    number_of_states = env.observation_space.n
    number_of_actions = env.action_space.n
    ## 1
    policy = np.random.randint(number_of_actions, size=(1,number_of_states))
#     policy = np.zeros((1,number_of_states))
    value_list = np.zeros((1, number_of_states))
    episode = 0
    sigma = discount
    
    ## 2
    policy_stable = False
    while not policy_stable:
        episode += 1
        eval_acc = True
        while eval_acc:
            eps = 0
            for s in range(number_of_states):
                # first row
                v = value_list[0][s]

                # get the new value 
                a = policy[0][s]
                total_val_new_state = 0
                for prob, new_state, reward, done in env.P[s][a]:
                    value_new_state = value_list[0][new_state]
                    # second row
                    cand_value = 0
                    if done:
                        cand_value = reward                     
                    else:
                        cand_value = reward + sigma*value_new_state
                    total_val_new_state += cand_value*prob 
                value_list[0][s] = total_val_new_state
                    
                # third row
                eps = max(eps, np.abs(v-value_list[0][s]))
            if eps < epsilon:
                eval_acc = False


        ## 3
        policy_stable = True
        for s in range(number_of_states):

            # assign 
            old_action = policy[0][s]
            # get the argmax a here
            max_value = -np.inf
            for a in range(number_of_actions):
                # get the new value 
                total_cand_value = 0
                for prob, new_state, reward, done in env.P[s][a]:
                    value_new_state = value_list[0][new_state]
                    cand_value = 0
                    if done:
                        cand_value = reward
                    else:
                        cand_value = reward + sigma*value_new_state
                    total_cand_value += prob*cand_value
                if total_cand_value > max_value:
                    max_value = total_cand_value
                    policy[0][s] = a

            # if old-action != policy[s]
            if old_action != policy[0][s]:
                policy_stable = False
    
    
    end = timer()
    time_spent = timedelta(seconds=end-start)
    print("Solved in: {} episodes and {} seconds".format(episode, time_spent))
    return policy[0], episode, time_spent

# %%
def train_and_test_pi_vi(env, discount=[0.9], epsilon=[1e-9], mute=False):
    
    vi_dict = {}
    
    for dis in discount:
        vi_dict[dis] = {}
        for eps in epsilon:
            vi_dict[dis][eps] = {}
            
            # run value iteration
            vi_policy, vi_solve_iter, vi_solve_time = value_iteration(env, dis, eps)
            vi_mrews, vi_meps, _, __ = test_policy(env, vi_policy)    
            vi_dict[dis][eps]["mean_reward"] = vi_mrews
            vi_dict[dis][eps]["mean_eps"] = vi_meps
            vi_dict[dis][eps]["iteration"] = vi_solve_iter
            vi_dict[dis][eps]["time_spent"] = vi_solve_time
            vi_dict[dis][eps]["policy"] = vi_policy
            if not mute:
                print("Value iteration for {} discount and {} eps is done".format(dis, eps))
                print("Iteration: {} time: {}".format(vi_solve_iter, vi_solve_time))
                print("Mean reward: {} - mean eps: {}".format(vi_mrews, vi_meps))
    # run policy iteration
    pi_dict = {}
    for dis in discount:
        pi_dict[dis] = {}
        for eps in epsilon:
            pi_dict[dis][eps] = {}

            pi_policy, pi_solve_iter, pi_solve_time = policy_iteration(env, dis, eps)
            pi_mrews, pi_meps, _, __ = test_policy(env, pi_policy)    
            pi_dict[dis][eps]["mean_reward"] = pi_mrews
            pi_dict[dis][eps]["mean_eps"] = pi_meps
            pi_dict[dis][eps]["iteration"] = pi_solve_iter
            pi_dict[dis][eps]["time_spent"] = pi_solve_time
            pi_dict[dis][eps]["policy"] = pi_policy
            if not mute:
                print("Policy iteration for {} discount is done".format(dis))
                print("Iteration: {} time: {}".format(pi_solve_iter, pi_solve_time))
                print("Mean reward: {} - mean eps: {}".format(pi_mrews, pi_meps))

    
    return vi_dict, pi_dict

# %%
def map_discretize(the_map):
    size = len(the_map)
    dis_map = np.zeros((size,size))
    for i, row in enumerate(the_map):
        for j, loc in enumerate(row):
            if loc == "S":
                dis_map[i, j] = 0
            elif loc == "F":
                dis_map[i, j] = 0
            elif loc == "H":
                dis_map[i, j] = -1
            elif loc == "G":
                dis_map[i, j] = 1
    return dis_map


def policy_numpy(policy):
    size = int(np.sqrt(len(policy)))
    pol = np.asarray(policy)
    pol = pol.reshape((size, size))
    return pol


def see_policy(map_size, policy):
    map_name = str(map_size)+"x"+str(map_size)
    data = map_discretize(MAPS[map_name])
    np_pol = policy_numpy(policy)
    plt.imshow(data, interpolation="nearest")

    for i in range(np_pol[0].size):
        for j in range(np_pol[0].size):
            arrow = '\u2190'
            if np_pol[i, j] == 1:
                arrow = '\u2193'
            elif np_pol[i, j] == 2:
                arrow = '\u2192'
            elif np_pol[i, j] == 3:
                arrow = '\u2191'
            text = plt.text(j, i, arrow,
                           ha="center", va="center", color="w")
    plt.show()

# %%
def plot_the_dict(dictionary, value="Score", size=4, variable="Discount Rate", log=False):

    plt.figure(figsize=(12, 8))
    title = "Average and Max {} on {}x{} Frozen Lake".format(value, size, size)
    the_val = value
    value = "Average {}".format(the_val)
    val_type = "Type of {}".format(the_val)
    the_df = pd.DataFrame(columns=[variable, value, val_type])
    for k, v in dictionary.items():
        for val in v:
            if not log:
                dic = {variable: k, value: float(val), val_type: "Average with std"}
            else:
                dic = {variable: np.log10(k), value: float(val), val_type: "Average with std"}                
            the_df = the_df.append(dic, ignore_index=True)
        if not log:
            dic = {variable: k, value: float(max(v)), val_type: "Max"}
        else:
            dic = {variable: np.log10(k), value: float(max(v)), val_type: "Max"}
        the_df = the_df.append(dic, ignore_index=True)
    sns.lineplot(x=variable, y=value, hue=val_type, style=val_type, markers=True, data=the_df).set(title=title)

# %%
def convert_dict_to_dict(the_dict):
    
    # return for discount
    discount_rewards = {}
    discount_iterations = {}
    discount_times = {}


    for disc in the_dict:
        discount_rewards[disc] = []    
        discount_iterations[disc] = []    
        discount_times[disc] = []

        for eps in the_dict[disc]:
            discount_rewards[disc].append(the_dict[disc][eps]['mean_reward'])
            discount_iterations[disc].append(the_dict[disc][eps]['iteration'])        
            discount_times[disc].append(the_dict[disc][eps]['time_spent'].total_seconds())  

            
    epsilon_rewards = {}
    epsilon_iterations = {}
    epsilon_times = {}
    for eps in the_dict[0.5]:
        epsilon_rewards[eps] = []    
        epsilon_iterations[eps] = []    
        epsilon_times[eps] = []
    
        for disc in vi_dict:
            epsilon_rewards[eps].append(the_dict[disc][eps]['mean_reward'])
            epsilon_iterations[eps].append(the_dict[disc][eps]['iteration'])        
            epsilon_times[eps].append(the_dict[disc][eps]['time_spent'].total_seconds()) 
            
    return discount_rewards, discount_iterations, discount_times, epsilon_rewards, epsilon_iterations, epsilon_times

# %% [markdown]
# ## 4x4

# %%
env = gym.make("FrozenLake-v1")
vi_dict, pi_dict = train_and_test_pi_vi(env, discount=[0.5, 0.75, 0.9, 0.95, 0.99, 0.9999], 
                                        epsilon=[1e-3, 1e-6, 1e-9, 1e-12, 1e-15], mute=True)
# Out:
# Solved in: 7 episodes and 0:00:00.001991 seconds
# Solved in: 16 episodes and 0:00:00.004378 seconds
# Solved in: 25 episodes and 0:00:00.007046 seconds
# Solved in: 34 episodes and 0:00:00.009517 seconds
# Solved in: 44 episodes and 0:00:00.012436 seconds
# Solved in: 12 episodes and 0:00:00.003577 seconds
# Solved in: 33 episodes and 0:00:00.009632 seconds
# Solved in: 53 episodes and 0:00:00.015282 seconds
# Solved in: 73 episodes and 0:00:00.021231 seconds
# Solved in: 94 episodes and 0:00:00.025813 seconds
# Solved in: 27 episodes and 0:00:00.007599 seconds
# Solved in: 78 episodes and 0:00:00.021443 seconds
# Solved in: 129 episodes and 0:00:00.035595 seconds
# Solved in: 179 episodes and 0:00:00.047943 seconds
# Solved in: 230 episodes and 0:00:00.063456 seconds
# Solved in: 44 episodes and 0:00:00.011842 seconds
# Solved in: 128 episodes and 0:00:00.035021 seconds
# Solved in: 213 episodes and 0:00:00.058615 seconds
# Solved in: 297 episodes and 0:00:00.081503 seconds
# Solved in: 381 episodes and 0:00:00.109646 seconds
# Solved in: 105 episodes and 0:00:00.030411 seconds
# Solved in: 305 episodes and 0:00:00.084794 seconds
# Solved in: 504 episodes and 0:00:00.138670 seconds
# Solved in: 704 episodes and 0:00:00.190431 seconds
# Solved in: 903 episodes and 0:00:00.245252 seconds
# Solved in: 149 episodes and 0:00:00.043085 seconds
# Solved in: 429 episodes and 0:00:00.117471 seconds
# Solved in: 709 episodes and 0:00:00.190868 seconds
# Solved in: 989 episodes and 0:00:00.271334 seconds
# Solved in: 1266 episodes and 0:00:00.344493 seconds
# Solved in: 4 episodes and 0:00:00.002679 seconds
# Solved in: 3 episodes and 0:00:00.003896 seconds
# Solved in: 4 episodes and 0:00:00.007492 seconds
# Solved in: 6 episodes and 0:00:00.011426 seconds
# Solved in: 4 episodes and 0:00:00.012562 seconds
# Solved in: 4 episodes and 0:00:00.003656 seconds
# Solved in: 6 episodes and 0:00:00.011262 seconds
# Solved in: 4 episodes and 0:00:00.014633 seconds
# Solved in: 8 episodes and 0:00:00.026607 seconds
# Solved in: 6 episodes and 0:00:00.033337 seconds
# Solved in: 4 episodes and 0:00:00.005640 seconds
# Solved in: 4 episodes and 0:00:00.016067 seconds
# Solved in: 4 episodes and 0:00:00.036200 seconds
# Solved in: 6 episodes and 0:00:00.052772 seconds
# Solved in: 4 episodes and 0:00:00.052253 seconds
# Solved in: 3 episodes and 0:00:00.007197 seconds
# Solved in: 3 episodes and 0:00:00.019287 seconds
# Solved in: 3 episodes and 0:00:00.029464 seconds
# Solved in: 4 episodes and 0:00:00.069771 seconds
# Solved in: 5 episodes and 0:00:00.091517 seconds
# Solved in: 6 episodes and 0:00:00.017859 seconds
# Solved in: 3 episodes and 0:00:00.047131 seconds
# Solved in: 3 episodes and 0:00:00.079476 seconds
# Solved in: 4 episodes and 0:00:00.143200 seconds
# Solved in: 7 episodes and 0:00:00.243352 seconds
# Solved in: 7 episodes and 0:00:00.027213 seconds
# Solved in: 3 episodes and 0:00:00.058051 seconds
# Solved in: 4 episodes and 0:00:00.135506 seconds
# Solved in: 4 episodes and 0:00:00.193117 seconds
# Solved in: 4 episodes and 0:00:00.207373 seconds

# %%
vi_dict[0.99]
# Out:
# {0.001: {'mean_reward': 0.735,
#   'mean_eps': 100.0,
#   'iteration': 105,
#   'time_spent': datetime.timedelta(microseconds=30411),
#   'policy': array([0., 3., 3., 3., 0., 0., 0., 0., 3., 1., 0., 0., 0., 2., 1., 0.])},
#  1e-06: {'mean_reward': 0.73,
#   'mean_eps': 100.0,
#   'iteration': 305,
#   'time_spent': datetime.timedelta(microseconds=84794),
#   'policy': array([0., 3., 3., 3., 0., 0., 0., 0., 3., 1., 0., 0., 0., 2., 1., 0.])},
#  1e-09: {'mean_reward': 0.739,
#   'mean_eps': 100.0,
#   'iteration': 504,
#   'time_spent': datetime.timedelta(microseconds=138670),
#   'policy': array([0., 3., 3., 3., 0., 0., 0., 0., 3., 1., 0., 0., 0., 2., 1., 0.])},
#  1e-12: {'mean_reward': 0.731,
#   'mean_eps': 100.0,
#   'iteration': 704,
#   'time_spent': datetime.timedelta(microseconds=190431),
#   'policy': array([0., 3., 3., 3., 0., 0., 0., 0., 3., 1., 0., 0., 0., 2., 1., 0.])},
#  1e-15: {'mean_reward': 0.748,
#   'mean_eps': 100.0,
#   'iteration': 903,
#   'time_spent': datetime.timedelta(microseconds=245252),
#   'policy': array([0., 3., 3., 3., 0., 0., 0., 0., 3., 1., 0., 0., 0., 2., 1., 0.])}}

# %%
pi_dict[0.9999]
# Out:
# {0.001: {'mean_reward': 0.737,
#   'mean_eps': 100.0,
#   'iteration': 7,
#   'time_spent': datetime.timedelta(microseconds=27213),
#   'policy': array([0, 3, 3, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])},
#  1e-06: {'mean_reward': 0.735,
#   'mean_eps': 100.0,
#   'iteration': 3,
#   'time_spent': datetime.timedelta(microseconds=58051),
#   'policy': array([0, 3, 3, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])},
#  1e-09: {'mean_reward': 0.731,
#   'mean_eps': 100.0,
#   'iteration': 4,
#   'time_spent': datetime.timedelta(microseconds=135506),
#   'policy': array([0, 3, 3, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])},
#  1e-12: {'mean_reward': 0.732,
#   'mean_eps': 100.0,
#   'iteration': 4,
#   'time_spent': datetime.timedelta(microseconds=193117),
#   'policy': array([0, 3, 3, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])},
#  1e-15: {'mean_reward': 0.735,
#   'mean_eps': 100.0,
#   'iteration': 4,
#   'time_spent': datetime.timedelta(microseconds=207373),
#   'policy': array([0, 3, 3, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])}}

# %%
pol = vi_dict[0.99][1e-12]['policy']
vi4 = convert_dict_to_dict(vi_dict)
see_policy(4, pol)

# %%
plot_the_dict(vi4[0], value="Score", size=4)

# %%
plot_the_dict(vi4[1], value="Iteration", size=4)

# %%
plot_the_dict(vi4[2], value="Time", size=4)

# %%
plot_the_dict(vi4[3], value="Score", size=4, variable="Log Epsilon Value", log=True)

# %%
plot_the_dict(vi4[4], value="Iteration", size=4, variable="Log Epsilon Value", log=True)

# %%
plot_the_dict(vi4[5], value="Time", size=4, variable="Log Epsilon Value", log=True)

# %%
pol = pi_dict[0.99][1e-12]['policy']
pi4 = convert_dict_to_dict(pi_dict)
see_policy(4, pol)

# %%
plot_the_dict(pi4[0], value="Score", size=4)

# %%
plot_the_dict(pi4[1], value="Iteration", size=4)

# %%
plot_the_dict(pi4[2], value="Time", size=4)

# %%
plot_the_dict(pi4[3], value="Score", size=4, variable="Log Epsilon Value", log=True)

# %%
plot_the_dict(pi4[4], value="Iteration", size=4, variable="Log Epsilon Value", log=True)

# %%
plot_the_dict(pi4[5], value="Time", size=4, variable="Log Epsilon Value", log=True)

# %% [markdown]
# ## 16 x 16

# %%
env = FrozenLakeEnv(desc=MAPS["16x16"])
vi_dict16, pi_dict16 = train_and_test_pi_vi(env, discount=[0.5, 0.75, 0.9, 0.95, 0.99, 0.9999], 
                                          epsilon=[1e-3, 1e-6, 1e-9, 1e-12, 1e-15], mute=True)
# Out:
# Solved in: 7 episodes and 0:00:00.020396 seconds
# Solved in: 15 episodes and 0:00:00.044995 seconds
# Solved in: 24 episodes and 0:00:00.071693 seconds
# Solved in: 34 episodes and 0:00:00.100380 seconds
# Solved in: 43 episodes and 0:00:00.132353 seconds
# Solved in: 12 episodes and 0:00:00.034108 seconds
# Solved in: 31 episodes and 0:00:00.095897 seconds
# Solved in: 54 episodes and 0:00:00.167637 seconds
# Solved in: 77 episodes and 0:00:00.241662 seconds
# Solved in: 100 episodes and 0:00:00.305305 seconds
# Solved in: 20 episodes and 0:00:00.059682 seconds
# Solved in: 77 episodes and 0:00:00.227701 seconds
# Solved in: 138 episodes and 0:00:00.437341 seconds
# Solved in: 199 episodes and 0:00:00.599042 seconds
# Solved in: 260 episodes and 0:00:00.824489 seconds
# Solved in: 31 episodes and 0:00:00.089211 seconds
# Solved in: 147 episodes and 0:00:00.458822 seconds
# Solved in: 268 episodes and 0:00:00.805742 seconds
# Solved in: 384 episodes and 0:00:01.172312 seconds
# Solved in: 499 episodes and 0:00:01.585121 seconds
# Solved in: 93 episodes and 0:00:00.284779 seconds
# Solved in: 518 episodes and 0:00:01.549965 seconds
# Solved in: 903 episodes and 0:00:02.723044 seconds
# Solved in: 1287 episodes and 0:00:03.849650 seconds
# Solved in: 1672 episodes and 0:00:05.077536 seconds
# Solved in: 302 episodes and 0:00:00.919367 seconds
# Solved in: 1449 episodes and 0:00:04.363489 seconds
# Solved in: 2587 episodes and 0:00:07.846509 seconds
# Solved in: 3723 episodes and 0:00:11.222067 seconds
# Solved in: 4854 episodes and 0:00:14.671331 seconds
# Solved in: 26 episodes and 0:00:00.124287 seconds
# Solved in: 14 episodes and 0:00:00.097150 seconds
# Solved in: 21 episodes and 0:00:00.187372 seconds
# Solved in: 18 episodes and 0:00:00.270489 seconds
# Solved in: 7 episodes and 0:00:00.174624 seconds
# Solved in: 26 episodes and 0:00:00.140621 seconds
# Solved in: 15 episodes and 0:00:00.141206 seconds
# Solved in: 7 episodes and 0:00:00.182322 seconds
# Solved in: 5 episodes and 0:00:00.273222 seconds
# Solved in: 16 episodes and 0:00:00.915119 seconds
# Solved in: 22 episodes and 0:00:00.135898 seconds
# Solved in: 18 episodes and 0:00:00.475994 seconds
# Solved in: 19 episodes and 0:00:01.130039 seconds
# Solved in: 19 episodes and 0:00:01.909205 seconds
# Solved in: 19 episodes and 0:00:02.652119 seconds
# Solved in: 15 episodes and 0:00:00.126844 seconds
# Solved in: 19 episodes and 0:00:00.953395 seconds
# Solved in: 8 episodes and 0:00:01.113799 seconds
# Solved in: 18 episodes and 0:00:03.525916 seconds
# Solved in: 19 episodes and 0:00:04.856919 seconds
# Solved in: 21 episodes and 0:00:00.457608 seconds
# Solved in: 19 episodes and 0:00:03.504055 seconds
# Solved in: 19 episodes and 0:00:08.080948 seconds
# Solved in: 8 episodes and 0:00:05.809971 seconds
# Solved in: 20 episodes and 0:00:18.279823 seconds
# Solved in: 18 episodes and 0:00:01.036511 seconds
# Solved in: 7 episodes and 0:00:04.115121 seconds
# Solved in: 8 episodes and 0:00:10.063387 seconds
# Solved in: 20 episodes and 0:00:47.439319 seconds
# Solved in: 20 episodes and 0:01:04.716168 seconds

# %%
pol = vi_dict16[0.9999][1e-15]['policy']
vi16 = convert_dict_to_dict(vi_dict16)
see_policy(16, pol)

# %%
plot_the_dict(vi16[0], value="Score", size=16)

# %%
plot_the_dict(vi16[1], value="Iteration", size=16)

# %%
plot_the_dict(vi16[2], value="Time", size=16)

# %%
pi16 = convert_dict_to_dict(pi_dict16)

# %%
plot_the_dict(pi16[0], value="Score", size=16)

# %%
plot_the_dict(pi16[1], value="Iteration", size=16)

# %%
plot_the_dict(pi16[2], value="Time", size=16)

# %%
import dill
dill.dump_session('vi_pi_all.db')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-04f79dad2e0c> in <module>
# ----> 1 import dill
#       2 dill.dump_session('vi_pi_all.db')
#
# ModuleNotFoundError: No module named 'dill'
